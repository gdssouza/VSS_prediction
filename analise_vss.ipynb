# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("vss_xyz_dia_2017-2019",index_col=0)
df.DATE = pd.to_datetime(df.DATE)
df.set_index('DATE',inplace=True)
df
# Out:
#                     TIME  DOY     VSSX    VSSY     VSSZ  VSSG             F
# DATE
# 2017-01-01  00:00:00.000    1  16701.6 -6959.5 -14647.2  -0.3  23279.144113
# 2017-01-02  00:00:00.000    2  16714.7 -6967.7 -14644.2  -0.3  23289.109752
# 2017-01-03  00:00:00.000    3  16716.4 -6964.4 -14645.7  -0.2  23290.286061
# 2017-01-04  00:00:00.000    4  16710.7 -6959.6 -14647.0  -0.3  23285.577847
# 2017-01-05  00:00:00.000    5  16691.8 -6967.6 -14650.9  -0.4  23276.866366
# ...                  ...  ...      ...     ...      ...   ...           ...
# 2019-12-27  00:00:00.000  361  16437.9 -6910.5 -14976.9   0.1  23286.629217
# 2019-12-28  00:00:00.000  362  16436.9 -6911.9 -14975.3   0.1  23285.309818
# 2019-12-29  00:00:00.000  363  16435.5 -6911.4 -14977.9   0.2  23285.845456
# 2019-12-30  00:00:00.000  364  16435.4 -6913.1 -14977.4   0.2  23285.957904
# 2019-12-31  00:00:00.000  365  16450.2 -6911.3 -14977.1   0.2  23295.679259
#
# [1081 rows x 7 columns]

# %%
#visualizando
plt.figure(figsize=(18,9))

plt.subplot(4,1,1)
df.VSSX.plot()
plt.ylabel("X (nT)")

plt.subplot(4,1,2)
df.VSSY.plot()
plt.ylabel("Y (nT)")

plt.subplot(4,1,3)
df.VSSZ.plot()
plt.ylabel("Z (nT)")

plt.subplot(4,1,4)
df.F.plot()
plt.ylabel("F (nT)")

plt.show()

# %% [markdown]
# ### Analisando tendências

# %%
periodo = 21
#visualizando
plt.figure(figsize=(18,9))

plt.subplot(4,1,1)
df.VSSX.rolling(periodo).mean().plot()
plt.ylabel("X (nT)")

plt.subplot(4,1,2)
df.VSSY.rolling(periodo).mean().plot()
plt.ylabel("Y (nT)")

plt.subplot(4,1,3)
df.VSSZ.rolling(periodo).mean().plot()
plt.ylabel("Z (nT)")

plt.subplot(4,1,4)
df.F.rolling(periodo).mean().plot()
plt.ylabel("F (nT)")

plt.show()

# %% [markdown]
# ### Analisando sazonalidade

# %%
#visualizando
plt.figure(figsize=(18,9))

plt.subplot(4,1,1)
df.VSSX.diff(1).plot()
plt.ylabel("X (nT)")

plt.subplot(4,1,2)
df.VSSY.diff(1).plot()
plt.ylabel("Y (nT)")

plt.subplot(4,1,3)
df.VSSZ.diff(1).plot()
plt.ylabel("Z (nT)")

plt.subplot(4,1,4)
df.F.diff(1).plot()
plt.ylabel("F (nT)")

plt.show()
